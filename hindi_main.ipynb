# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import pandas as pd
import math
import os
from skimage.measure import regionprops
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
img = cv2.imread('C:\\Users\\Gitesh Singh Phogat\\Desktop\\sample.tif')
plt.imshow(img, 'gray')
plt.show()

# %%
def otsu(img):
    kernal_size=(3,3)
    b = cv2.blur(img,kernal_size) # mean filter
    ret3,th3 = cv2.threshold(b,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
    print(ret3)
    return th3

oimg=otsu(gray_img)  
plt.imshow(oimg,'gray')
plt.show()
# Out:
# 142.0

# %%
def crop_image(img,tol=0):
    mask = img>tol
    return img[np.ix_(mask.any(1),mask.any(0))]

cimg=crop_image(oimg,0)
plt.imshow(cimg,'gray')
plt.show()

# %%
def thinning(img):
    #img = cimg
    size = np.size(img)
    skel = np.zeros(img.shape,np.uint8)
    ret,img = cv2.threshold(img,127,255,0)
    element = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
    done = False
    while( not done):
        eroded = cv2.erode(img,element)
        temp = cv2.dilate(eroded,element)
        temp = cv2.subtract(img,temp)
        skel = cv2.bitwise_or(skel,temp)
        img = eroded.copy()
        zeros = size - cv2.countNonZero(img)
        if zeros==size:
            done = True
    return skel

timg=thinning(cimg)
plt.imshow(timg,'gray')
plt.show()

# %%
def thickning(img):
    # Apply Canny edge detection to the blurred image
    edges = cv2.Canny(img, 100, 200)

    # Dilate the edges to make them thicker
    kernel = np.ones((5,5), np.uint8)
    return cv2.dilate(edges, kernel, iterations=1)

    cv2.imshow('Dilated Edges', dilated_edges)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

timg=thickning(cimg)
plt.imshow(timg,'gray')
plt.show()

# %%
def preprocessing(train_path):
    x_train=[]
    y_train=[]
    for sub_path in os.listdir(train_path):
        image_path = train_path + '\\' +sub_path 
        count=0
        for img in os.listdir(image_path):
            count+=1
            temp = cv2.imread(image_path + '/' + img, 0)
            temp= otsu(temp)
#             temp=thinning(temp)
            temp=thickning(temp)
            temp=crop_image(temp)
            temp = temp.astype('float32') / 255.0  # Normalization
            
            if(count<=30):
                x_train.append(temp)
            else:
                y_train.append(temp)
        
    return x_train,y_train

# %%
train_path='C:\\Users\\Gitesh Singh Phogat\\Desktop\\Signature verification\\BHSig260\\Hindi'
F,R=preprocessing(train_path)

# %%
def Ratio(img):
    a = 0
    for row in range(len(img)):
        for col in range(len(img[0])):
            if img[row][col]==True:
                a = a+1
    total = img.shape[0] * img.shape[1]
    return a/total

# %%
def Centroid(img):
    numOfWhites = 0
    a = np.array([0,0])
    for row in range(len(img)):
        for col in range(len(img[0])):
            if img[row][col]==True:
                b = np.array([row,col])
                a = np.add(a,b)
                numOfWhites += 1
    rowcols = np.array([img.shape[0], img.shape[1]])
    centroid = a/numOfWhites
    centroid = centroid/rowcols
    return centroid[0], centroid[1]

# %%
def EccentricitySolidity(img):
    r = regionprops(img.astype("int"))
    return r[0].eccentricity, r[0].solidity

# %%
def SkewKurtosis(img):
    h,w = img.shape
    x = range(w)  # cols value
    y = range(h)  # rows value
    #calculate projections along the x and y axes
    xp = np.sum(img,axis=0)
    yp = np.sum(img,axis=1)
    #centroid
    cx = np.sum(x*xp)/np.sum(xp)
    cy = np.sum(y*yp)/np.sum(yp)
    #standard deviation
    x2 = (x-cx)**2
    y2 = (y-cy)**2
    sx = np.sqrt(np.sum(x2*xp)/np.sum(img))
    sy = np.sqrt(np.sum(y2*yp)/np.sum(img))
    
    #skewness
    x3 = (x-cx)**3
    y3 = (y-cy)**3
    skewx = np.sum(xp*x3)/(np.sum(img) * sx**3)
    skewy = np.sum(yp*y3)/(np.sum(img) * sy**3)

    #Kurtosis
    x4 = (x-cx)**4
    y4 = (y-cy)**4
    # 3 is subtracted to calculate relative to the normal distribution
    kurtx = np.sum(xp*x4)/(np.sum(img) * sx**4) - 3
    kurty = np.sum(yp*y4)/(np.sum(img) * sy**4) - 3

    return (skewx , skewy), (kurtx, kurty)

# %%
#mean
def meanStd(img):
    mean = np.mean(img)
    std = np.std(img)
    return mean, std

# %%
def getFeatures(img):
    ratio = Ratio(img)
    centroid = Centroid(img)
    eccentricity, solidity = EccentricitySolidity(img)
    skewness, kurtosis = SkewKurtosis(img)
    mean, std= meanStd(img)
    retVal = (ratio, centroid, eccentricity, solidity, skewness, kurtosis, mean, std)
    return retVal

# %%
def getCSVFeatures(img):
    temp = getFeatures(img)
    features = (temp[0], temp[1][0], temp[1][1], temp[2], temp[3], temp[4][0], temp[4][1], temp[5][0], temp[5][1], temp[6], temp[7])
    return features

# %%
def makeCSV():
    if not(os.path.exists('C:\\Users\\Gitesh Singh Phogat\\Desktop\\signature verification\\Features')):
        os.mkdir('C:\\Users\\Gitesh Singh Phogat\\Desktop\\signature verification/Features')
        print('New folder "Features" created')
        
    cF=0
    cR=0
    for person in range(1,161):
        per = ('00'+str(person))[-3:]
        print('Saving features for person id-',per)
        
        with open('C:\\Users\\Gitesh Singh Phogat\\Desktop\\signature verification\\Features/features_'+per+'.csv', 'w') as handle:
            handle.write('ratio,cent_y,cent_x,eccentricity,solidity,skew_x,skew_y,kurt_x,kurt_y,mean,std,output\n')
            # Training set
            
            #real image
            i=cR
            z=1
            while(i<len(R)):
                features = getCSVFeatures(R[i])
#                 print(i)
#                 plt.imshow(R[i])
#                 plt.show()
                handle.write(','.join(map(str, features))+',1\n')
                i+=1
                if(z==24):
                    break
                z+=1
            cR=i
            
            #forged image
            i=cF
            z=1
            while(i<len(F)):
                features = getCSVFeatures(F[i])
                handle.write(','.join(map(str, features))+',0\n')
                i+=1
                if(z==30):
                    break
                z+=1
            cF=i

# %%
makeCSV()
# Out:
# Saving features for person id- 001
# Saving features for person id- 002
# Saving features for person id- 003
# Saving features for person id- 004
# Saving features for person id- 005
# Saving features for person id- 006
# Saving features for person id- 007
# Saving features for person id- 008
# Saving features for person id- 009
# Saving features for person id- 010
# Saving features for person id- 011
# Saving features for person id- 012
# Saving features for person id- 013
# Saving features for person id- 014
# Saving features for person id- 015
# Saving features for person id- 016
# Saving features for person id- 017
# Saving features for person id- 018
# Saving features for person id- 019
# Saving features for person id- 020
# Saving features for person id- 021
# Saving features for person id- 022
# Saving features for person id- 023
# Saving features for person id- 024
# Saving features for person id- 025
# Saving features for person id- 026
# Saving features for person id- 027
# Saving features for person id- 028
# Saving features for person id- 029
# Saving features for person id- 030
# Saving features for person id- 031
# Saving features for person id- 032
# Saving features for person id- 033
# Saving features for person id- 034
# Saving features for person id- 035
# Saving features for person id- 036
# Saving features for person id- 037
# Saving features for person id- 038
# Saving features for person id- 039
# Saving features for person id- 040
# Saving features for person id- 041
# Saving features for person id- 042
# Saving features for person id- 043
# Saving features for person id- 044
# Saving features for person id- 045
# Saving features for person id- 046
# Saving features for person id- 047
# Saving features for person id- 048
# Saving features for person id- 049
# Saving features for person id- 050
# Saving features for person id- 051
# Saving features for person id- 052
# Saving features for person id- 053
# Saving features for person id- 054
# Saving features for person id- 055
# Saving features for person id- 056
# Saving features for person id- 057
# Saving features for person id- 058
# Saving features for person id- 059
# Saving features for person id- 060
# Saving features for person id- 061
# Saving features for person id- 062
# Saving features for person id- 063
# Saving features for person id- 064
# Saving features for person id- 065
# Saving features for person id- 066
# Saving features for person id- 067
# Saving features for person id- 068
# Saving features for person id- 069
# Saving features for person id- 070
# Saving features for person id- 071
# Saving features for person id- 072
# Saving features for person id- 073
# Saving features for person id- 074
# Saving features for person id- 075
# Saving features for person id- 076
# Saving features for person id- 077
# Saving features for person id- 078
# Saving features for person id- 079
# Saving features for person id- 080
# Saving features for person id- 081
# Saving features for person id- 082
# Saving features for person id- 083
# Saving features for person id- 084
# Saving features for person id- 085
# Saving features for person id- 086
# Saving features for person id- 087
# Saving features for person id- 088
# Saving features for person id- 089
# Saving features for person id- 090
# Saving features for person id- 091
# Saving features for person id- 092
# Saving features for person id- 093
# Saving features for person id- 094
# Saving features for person id- 095
# Saving features for person id- 096
# Saving features for person id- 097
# Saving features for person id- 098
# Saving features for person id- 099
# Saving features for person id- 100
# Saving features for person id- 101
# Saving features for person id- 102
# Saving features for person id- 103
# Saving features for person id- 104
# Saving features for person id- 105
# Saving features for person id- 106
# Saving features for person id- 107
# Saving features for person id- 108
# Saving features for person id- 109
# Saving features for person id- 110
# Saving features for person id- 111
# Saving features for person id- 112
# Saving features for person id- 113
# Saving features for person id- 114
# Saving features for person id- 115
# Saving features for person id- 116
# Saving features for person id- 117
# Saving features for person id- 118
# Saving features for person id- 119
# Saving features for person id- 120
# Saving features for person id- 121
# Saving features for person id- 122
# Saving features for person id- 123
# Saving features for person id- 124
# Saving features for person id- 125
# Saving features for person id- 126
# Saving features for person id- 127
# Saving features for person id- 128
# Saving features for person id- 129
# Saving features for person id- 130
# Saving features for person id- 131
# Saving features for person id- 132
# Saving features for person id- 133
# Saving features for person id- 134
# Saving features for person id- 135
# Saving features for person id- 136
# Saving features for person id- 137
# Saving features for person id- 138
# Saving features for person id- 139
# Saving features for person id- 140
# Saving features for person id- 141
# Saving features for person id- 142
# Saving features for person id- 143
# Saving features for person id- 144
# Saving features for person id- 145
# Saving features for person id- 146
# Saving features for person id- 147
# Saving features for person id- 148
# Saving features for person id- 149
# Saving features for person id- 150
# Saving features for person id- 151
# Saving features for person id- 152
# Saving features for person id- 153
# Saving features for person id- 154
# Saving features for person id- 155
# Saving features for person id- 156
# Saving features for person id- 157
# Saving features for person id- 158
# Saving features for person id- 159
# Saving features for person id- 160

# %%
# Define the folder containing the CSV files
folder_path = 'C:\\Users\\Gitesh Singh Phogat\\Desktop\\signature verification\\Features'

# Create empty lists to store the data and labels
data = []
labels = []

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    df = pd.read_csv(os.path.join(folder_path, filename))
    
    # Replace NaN values with 0
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    df.fillna(0, inplace=True)
    
    data.append(df.iloc[:, :-1].values)
    labels.append(df.iloc[:, -1].values)
    
# Flatten the data and labels lists
data = [item for sublist in data for item in sublist]
labels = [item for sublist in labels for item in sublist]

X_train, X_test, Y_train, Y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
#Decision tree classifier
classifier= DecisionTreeClassifier(max_depth=10)
classifier.fit(X_train,Y_train)

X_train_prediction=classifier.predict(X_train)
dt_training_accuracy= accuracy_score(X_train_prediction,Y_train)

X_test_prediction=classifier.predict(X_test)
dt_test_accuracy= accuracy_score(X_test_prediction,Y_test)

print("Training accuracy:", dt_training_accuracy*100)
print("Testing accuracy:", dt_test_accuracy*100)

print(classification_report(Y_test,X_test_prediction))

cm = confusion_matrix(Y_test, X_test_prediction)
print(cm)

sns.heatmap(cm, annot=True, cmap='Greens')
plt.show()
# Out:
# Training accuracy: 82.88483796296296
# Testing accuracy: 73.4375
#               precision    recall  f1-score   support
#
#            0       0.72      0.85      0.78       972
#            1       0.75      0.58      0.66       756
#
#     accuracy                           0.73      1728
#    macro avg       0.74      0.72      0.72      1728
# weighted avg       0.74      0.73      0.73      1728
#
# [[827 145]
#  [314 442]]

# %%
from sklearn.ensemble import AdaBoostClassifier

# Define the AdaBoost classifier with decision tree as base estimator
clf = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=12), n_estimators=1000, random_state=42, )

# Train the classifier on the training data
clf.fit(X_train, Y_train)

# Evaluate the accuracy of the classifier on the test data
clf_preds = clf.predict(X_test)
accuracy = accuracy_score(clf_preds,Y_test)

train_accuracy=clf.score(X_train,Y_train)
print("Training Accuracy:", train_accuracy*100)
print("Testing Accuracy:", accuracy*100)

print(classification_report(Y_test,clf_preds))

cm = confusion_matrix(Y_test, clf_preds)
print(cm)

sns.heatmap(cm, annot=True, cmap='Greens')
plt.show()
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 84.72222222222221
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       972
#            1       0.88      0.76      0.81       756
#
#     accuracy                           0.85      1728
#    macro avg       0.85      0.84      0.84      1728
# weighted avg       0.85      0.85      0.85      1728
#
# [[890  82]
#  [182 574]]

# %%
# classify using random forest classifier
classifier = RandomForestClassifier(random_state=0, max_depth=12)
classifier.fit(X_train, Y_train)

X_train_prediction=classifier.predict(X_train)
rf_training_accuracy= accuracy_score(X_train_prediction,Y_train)

X_test_prediction=classifier.predict(X_test)
rf_test_accuracy= accuracy_score(X_test_prediction,Y_test)

print("Training accuracy:", rf_training_accuracy*100)
print("Testing accuracy:", rf_test_accuracy*100)

print(classification_report(Y_test,X_test_prediction))

cm = confusion_matrix(Y_test, X_test_prediction)
print(cm)

sns.heatmap(cm, annot=True, cmap='Greens')
plt.show()
# Out:
# Training accuracy: 93.08449074074075
# Testing accuracy: 80.49768518518519
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       972
#            1       0.85      0.67      0.75       756
#
#     accuracy                           0.80      1728
#    macro avg       0.82      0.79      0.80      1728
# weighted avg       0.81      0.80      0.80      1728
#
# [[882  90]
#  [247 509]]
